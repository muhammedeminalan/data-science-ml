# %%
import  numpy as np

# %%
my_list = [10,20,30,40]

# %%
type(my_list)
# Out:
# list

# %%
np.array(my_list)
# Out:
# array([10, 20, 30, 40])

# %%
my_numpy_array = np.array(my_list)

# %%
type(my_numpy_array)
# Out:
# numpy.ndarray

# %%
my_numpy_array.
# Out:
# np.int64(40)

# %%
np.ones(5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.random.random(5)
# Out:
# array([0.17233741, 0.16017498, 0.19072093, 0.58499779, 0.59475324])
